# %%
import socket
print(socket.gethostname())
print(socket.getfqdn())
# Out:
# jupyter-laltonaga
# jupyter-laltonaga

# %%
# !hostname
# !hostname -f
# Out:
# jupyter-laltonaga
# jupyter-laltonaga

# %%
# !hostname
# !hostname -f
# !echo $HOSTNAME
# Out:
# jupyter-laltonaga
# jupyter-laltonaga
# jupyter-laltonaga

# %%
# !ls -ld /mnt/processed/private/msds2026/slt3a
# !whoami
# !id
# Out:
# drwxrws---+ 3 root msds2026slt3a 4096 Apr 28 16:41 /mnt/processed/private/msds2026/slt3a
# laltonaga
# uid=4081(laltonaga) gid=796(msds2026) groups=796(msds2026),742(msds2026cpt3),751

# %%
# !cd /mnt/processed/private/msds2026/slt3a
# !touch test_permission.txt
# !ls -l test_permission.txt
# !rm test_permission.txt
# Out:
# -rw-r-----+ 1 laltonaga msds2026 0 Apr 28 16:58 test_permission.txt

# %%
# !ls /mnt/processed/private/msds2026/slt3a/'Lab 1'
# Out:
# 'Lab Notebook-Enzo.ipynb'  'Lab Notebook.ipynb'  'Terminal Notebook.ipynb'

# %%
# !pwd
# Out:
# /mnt/processed/private/msds2026/slt3a/Lab 1

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /mnt/processed/private/msds2026/slt3a/Lab 1/.git/

# %%
# !git branch -M main
